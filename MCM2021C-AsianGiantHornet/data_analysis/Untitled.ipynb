# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = np.genfromtxt('center.csv', delimiter=',')

# %%
x = []; ix = []; y1 = []; y2 = []; y3 = []
for i in data1:
    x.append(i[0])
    y1.append(i[1])
# print(x)
# print(y)
plt.plot(y1)
# plt.plot(y2, "r-")
# plt.plot(y3)
plt.xlabel("# days after the first positive")
plt.ylabel("# possible AGH population")
# plt.xticks(ix, x)
# print(ix, x)
# plt.show()
plt.savefig("population-10years.jpg", dpi = 500)
